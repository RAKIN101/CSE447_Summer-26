# %%
#install-PyCryptodome
#to do
# !pip install pycryptodome
# Out:
# Collecting pycryptodome
#   Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.4 kB)
# Downloading pycryptodome-3.23.0-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 13.6 MB/s eta 0:00:00
# Installing collected packages: pycryptodome
# Successfully installed pycryptodome-3.23.0

# %%
from Crypto.Cipher import DES
from Crypto.Random import get_random_bytes

# %%
def pad_text(text):
    # Ensure the plaintext length is a multiple of 8 bytes (DES block size)
    #generate and return the padded_text
    padLength = 8-(len(text)%8)
    if padLength != 8:
      padded_text = text + bytes([padLength]*padLength)
    else:
      padded_text = text
    return padded_text

# %%
def unpad_text(padded_text):
    # Remove the padding bytes to get the original plaintext
    #to do
    padLength = int(padded_text[-1])

    return padded_text[:-padLength]

# %%
def des_encrypt(plaintext, key):
    #encrypt DES(Mode:ECB) and return the ciphertext
    cipher = DES.new(key, DES.MODE_ECB)

    ciphertext = cipher.encrypt(plaintext)
    return ciphertext

# %%
plaintext = b"This is a secret text"
# Generate a random 64-bit (8-byte) key
#to do
key = get_random_bytes(8)

print("Original plaintext:", plaintext.decode('utf-8'))
print("Original key (in bytes):", key)

plaintext = pad_text(plaintext)

ciphertext = des_encrypt(plaintext, key)
print("Encrypted ciphertext (in bytes):", ciphertext)
# Out:
# Original plaintext: This is a secret text
# Original key (in bytes): b'\x8f\x11\x8c\x04\xc4\x9fj\x14'
# Encrypted ciphertext (in bytes): b'M\xdeF\x93\xc8\xe6u\xd4\xbe\x05\x01\xc1\xbe\x92\xbc\xae\xe3\xb1\x1c\\\x11\xca/\xb4'

# %%
def des_decrypt(ciphertext, key):
  cipher=DES.new(key,DES.MODE_ECB)
  plaintext=cipher.decrypt(ciphertext)
  return plaintext

# %%
# Replace these with your ciphertext and key
ciphertext = b'M\xdeF\x93\xc8\xe6u\xd4\xbe\x05\x01\xc1\xbe\x92\xbc\xae\xe3\xb1\x1c\\\x11\xca/\xb4'
key = b'\x8f\x11\x8c\x04\xc4\x9fj\x14'

dec_text = des_decrypt(ciphertext, key)
og_text  = unpad_text(dec_text)

print("Decrypted text:", og_text  .decode('utf-8'))
# Out:
# Decrypted text: This is a secret text

# %%
#Implement Double DES and check if your ciphertext matches the provided output.
plaintext = b"I am Batman"
KeyA = b'\x01\xadWR\xeb\x1a\xa2\x86'
KeyB = b'\xf7\xcf\xd6r\xd9\xa1\x141'
Given_Output = b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}'

#to do
plaintext = pad_text(plaintext)
ciphertext = des_encrypt(plaintext, KeyA)
ciphertext = des_encrypt(ciphertext, KeyB)

print(ciphertext)

ciphertext = des_decrypt(ciphertext, KeyB)
ciphertext = des_decrypt(ciphertext, KeyA)
plaintext = unpad_text(ciphertext)
print(plaintext)
# Out:
# b'\xd2Em\x06-1\xf7$\x0c\xaaI\xf0\xc3\x00\xbd}'
# b'I am Batman'

# %%
#Pattern Repetition in DES ECB Mode Ciphertext
plaintext = b"ABCDEFGHABCDEFGHABCDEFGH"
key = get_random_bytes(8)  # Generate a random 64-bit (8-byte) key

padtext = pad_text(plaintext)
c1 = des_encrypt(padtext,key)
print(c1)

#In DES, if the same plaintext block appears repeatedly and is encrypted with the same key,
#it produces the same ciphertext block each time.
#This repetition can reveal patterns in the data and reduce security
# Out:
# b'\x93\x91\x83\x0eX\x07\x84\x87\x93\x91\x83\x0eX\x07\x84\x87\x93\x91\x83\x0eX\x07\x84\x87'
